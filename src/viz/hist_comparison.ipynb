# %% [markdown]
# ## History Comparison
#
# This notebook is intended to contrast the effects of passing the full unedited history vs a summarized history.
#
# TODO:
# 1) Compare existing results where both full and summarized history were run (in a table)
# 2) Decide if the coverage of these results is sufficient
# 3) Report this comparison table in OpenReview
# 4) Depending on coverage, offer to add the table to the appendix

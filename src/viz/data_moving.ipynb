# %% [markdown]
# ## Moving Data
# The point of this notebook is to merge the many small DataFrames into one large one

# %% [markdown]
# ## Prep (Do this only once per execution)

# %%
import os

os.chdir("../..")

# %% [markdown]
# ## Loading Farm NoVar

# %%
import pandas as pd

df_list = []

df_list.append({'domain': 'Farm', 'model': 'Qwen8B', 'history': 'Full', 'df_path': "experiments/20260118_farm_novar/model_name_Qwen3-8B_prompt_fullhist/eval_results.csv"})
df_list.append({'domain': 'Farm', 'model': 'Qwen8B', 'history': 'Summarized', 'df_path': "experiments/20260118_farm_novar/model_name_Qwen3-8B_prompt_summhist/eval_results.csv"})
df_list.append({'domain': 'Farm', 'model': 'Qwen14B', 'history': 'Full', 'df_path': "experiments/20260118_farm_novar/model_name_Qwen3-14B_prompt_fullhist/eval_results.csv"})
df_list.append({'domain': 'Farm', 'model': 'Qwen14B', 'history': 'Summarized', 'df_path': "experiments/20260118_farm_novar/model_name_Qwen3-14B_prompt_summhist/eval_results.csv"})
df_list.append({'domain': 'Farm', 'model': 'Qwen32B', 'history': 'Full', 'df_path': "experiments/20260118_farm_novar/model_name_Qwen3-32B_prompt_fullhist/eval_results.csv"})
df_list.append({'domain': 'Farm', 'model': 'Qwen32B', 'history': 'Summarized', 'df_path': "experiments/20260118_farm_novar/model_name_Qwen3-32B_prompt_summhist/eval_results.csv"})
df_list.append({'domain': 'Bandit', 'model': 'Qwen14B', 'history': 'Full', 'df_path': "experiments/20260120_ab_novar/model_name_Qwen3-14B_prompt_fullhist/eval_results.csv"})
df_list.append({'domain': 'Bandit', 'model': 'Qwen14B', 'history': 'Summarized', 'df_path': "experiments/20260120_ab_novar/model_name_Qwen3-14B_prompt_summhist/eval_results.csv"})
df_list.append({'domain': 'Bandit', 'model': 'Qwen32B', 'history': 'Full', 'df_path': "experiments/20260120_ab_novar/model_name_Qwen3-32B_prompt_fullhist/eval_results.csv"})
df_list.append({'domain': 'Bandit', 'model': 'Qwen32B', 'history': 'Summarized', 'df_path': "experiments/20260120_ab_novar/model_name_Qwen3-32B_prompt_summhist/eval_results.csv"})

# %%
# Load in dataframes
for idx, df_metadata in enumerate(df_list):
    # Load
    temp_loaded_df = pd.read_csv(df_metadata['df_path'])
    # Add differentiating columns
    temp_loaded_df['Model'] = df_metadata['model']
    temp_loaded_df['History'] = df_metadata['history']
    temp_loaded_df['Domain'] = df_metadata['domain']
    # Save
    df_list[idx]['df'] = temp_loaded_df

# %%
# Merge the DFs
merged_df = pd.concat([
    df_list_item['df'] for df_list_item in df_list
    ], ignore_index=True)

# %%
merged_df.head()
# Out:
#                         subfolder  n_shuffles     nomenclature  \
# 0     alphanumeric_high_neg_scale          10     alphanumeric
# 1         alphanumeric_high_scale          10     alphanumeric
# 2      alphanumeric_low_neg_scale          10     alphanumeric
# 3          alphanumeric_low_scale          10     alphanumeric
# 4  sem_rel_helpful_high_neg_scale          10  sem_rel_helpful
#
#             scale  cum_reward_0_mean  cum_reward_0_std  step_reward_0_mean  \
# 0  high_neg_scale            -50.000         19.364917             -50.000
# 1      high_scale             52.500         17.500000              52.500
# 2   low_neg_scale             -0.525          0.207666              -0.525
# 3       low_scale              0.475          0.235850               0.475
# 4  high_neg_scale            -25.000          0.000000             -25.000
#
#    step_reward_0_std  step_regret_0_mean  step_regret_0_std  ...  \
# 0          19.364917              25.000          19.364917  ...
# ...

# %%
merged_df.to_csv("experiments/merged_eval_results.csv")

# %%
merged_df['Domain'].value_counts()
# Out:
# Domain
# Farm      119
# Bandit     80
# Name: count, dtype: int64

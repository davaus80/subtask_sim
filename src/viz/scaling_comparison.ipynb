# %% [markdown]
# ## Scaling Comparison
#
# This notebook is intended to display the scaling behaviour within the Qwen3 family of models.
#
# TODO:
# 1) Compare existing results where all Qwen models were run (in a table)
# 2) Decide if the coverage of these results is sufficient
# 3) Report this comparison table in OpenReview
# 4) Depending on coverage, offer to add the table to the appendix
